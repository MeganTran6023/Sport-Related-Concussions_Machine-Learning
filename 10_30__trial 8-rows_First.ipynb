# %%
#core
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("first_visit_data.csv")
df
# Out:
#       record_id  import_phq9_score  import_gad7_score  high_total_sx_severity  \
# 0             1               17.0               16.0                    40.0
# 1             2                3.0                4.0                    31.0
# 2             3               10.0                6.0                    35.0
# 3             4               20.0               15.0                     NaN
# 4             5                2.0                0.0                     9.0
# ...         ...                ...                ...                     ...
# 2995       3015                6.0                3.0                    22.0
# 2996       3016                3.0                2.0                     4.0
# 2997       3017               15.0                6.0                    10.0
# 2998       3018                5.0                3.0                    22.0
# 2999       3019               10.0                2.0                    45.0
#
#       cns_neurocog_index  cns_composite_mem  cns_verbal_mem  cns_visual_mem  \
# 0                    NaN                NaN             NaN             NaN
# 1                    NaN                NaN             NaN             NaN
# 2                    NaN                NaN             NaN             NaN
# 3                    NaN                NaN             NaN             NaN
# 4                    NaN                NaN             NaN             NaN
# ...                  ...                ...             ...             ...
# 2995                78.0               62.0            66.0            70.0
# 2996                86.0               84.0            89.0            85.0
# 2997               102.0               98.0            96.0            99.0
# 2998                80.0              105.0            90.0            19.0
# 2999                54.0               89.0            98.0            87.0
#
#       cns_psychomotor_speed  cns_rxn_time  ...  vor_horiz_nausea  \
# 0                       NaN           NaN  ...               1.0
# 1                       NaN           NaN  ...               0.0
# 2                       NaN           NaN  ...               0.0
# 3                       NaN           NaN  ...               NaN
# 4                       NaN           NaN  ...               0.0
# ...                     ...           ...  ...               ...
# 2995                   61.0          81.0  ...               0.0
# 2996                   89.0          90.0  ...               0.0
# 2997                   89.0         109.0  ...               0.0
# 2998                  109.0         114.0  ...               0.0
# 2999                   73.0          21.0  ...               0.0
#
#       vor_horiz_fogginess  vor_vert_headache  vor_vert_dizziness  \
# 0                     0.0                3.0                 1.0
# 1                     3.0                5.0                 2.0
# 2                     0.0                1.0                 2.0
# 3                     NaN                NaN                 NaN
# 4                     0.0                0.0                 0.0
# ...                   ...                ...                 ...
# 2995                  1.0                0.0                 0.0
# 2996                  0.0                1.0                 2.0
# 2997                  0.0                0.0                 0.0
# 2998                  0.0                3.0                 2.0
# 2999                  4.0                0.0                 6.0
#
#       vor_vert_nausea  vor_vert_fogginess  vmst_headache  vmst_dizziness  \
# 0                 1.0                 0.0            3.0             1.0
# 1                 0.0                 4.0            5.0             3.0
# 2                 0.0                 0.0            1.0             1.0
# 3                 NaN                 NaN            NaN             NaN
# 4                 0.0                 0.0            0.0             0.0
# ...               ...                 ...            ...             ...
# 2995              0.0                 1.0            NaN             NaN
# 2996              0.0                 0.0            1.0             2.0
# 2997              0.0                 0.0            0.0             0.0
# 2998              0.0                 0.0            3.0             2.0
# 2999              0.0                 4.0            0.0             4.0
#
#       vmst_nausea  vmst_fogginess
# 0             1.0             0.0
# 1             0.0             4.0
# 2             0.0             0.0
# 3             NaN             NaN
# 4             0.0             0.0
# ...           ...             ...
# 2995          NaN             NaN
# 2996          0.0             0.0
# 2997          0.0             0.0
# 2998          0.0             0.0
# 2999          0.0             4.0
#
# [3000 rows x 60 columns]

# %%
all_col = []

for x in df.columns:
    all_col.append(x)

all_col
# Out:
# ['record_id',
#  'import_phq9_score',
#  'import_gad7_score',
#  'high_total_sx_severity',
#  'cns_neurocog_index',
#  'cns_composite_mem',
#  'cns_verbal_mem',
#  'cns_visual_mem',
#  'cns_psychomotor_speed',
#  'cns_rxn_time',
#  'cns_complex_attention',
#  'cns_cognitive_flexibility',
#  'cns_processing_speed',
#  'cns_exec_fxn',
#  'cns_simple_attention',
#  'cns_motor_speed',
#  'cerv_flex',
#  'cerv_ext',
#  'l_lat_flex',
#  'r_lat_flex',
#  'subocc_flex',
#  'subocc_ext',
#  'l_cerv_rot',
#  'r_cerv_rot',
#  'bess_double_ec',
#  'bess_tandem_ec',
#  'bess_single_ec',
#  'voms_headache',
#  'voms_dizziness',
#  'voms_nausea',
#  'voms_fogginess',
#  'smoothpursuits_headache',
#  'smoothpursuits_dizziness',
#  'smoothpursuits_nausea',
#  'smoothpursuits_fogginess',
#  'saccades_horiz_headache',
#  'saccades_horiz_dizziness',
#  'saccades_horiz_nausea',
#  'saccades_horiz_fogginess',
#  'saccades_vert_headache',
#  'saccades_vert_dizziness',
#  'saccades_vert_nausea',
#  'saccades_vert_fogginess',
#  'npc_headache',
#  'npc_dizziness',
#  'npc_nausea',
#  'npc_fogginess',
#  'npc_measure',
#  'vor_horiz_headache',
#  'vor_horiz_dizziness',
#  'vor_horiz_nausea',
#  'vor_horiz_fogginess',
#  'vor_vert_headache',
#  'vor_vert_dizziness',
#  'vor_vert_nausea',
#  'vor_vert_fogginess',
#  'vmst_headache',
#  'vmst_dizziness',
#  'vmst_nausea',
#  'vmst_fogginess']

# %%
import pandas as pd

def clean_data(df, col_threshold=.9, row_threshold=.8, threshold_step=0.1):
    # Convert percentage thresholds to proportions
    col_threshold, row_threshold = col_threshold, row_threshold

    # Iteratively clean data
    while True:
        # Calculate null ratios
        row_null_ratios = df.isnull().mean(axis=1)
        col_null_ratios = df.isnull().mean()
        

        # Remove rows with null ratios above row threshold
        rows_to_drop = row_null_ratios[row_null_ratios > row_threshold].index
        df.drop(index=rows_to_drop, inplace=True)
        
        # Remove columns with null ratios above column threshold
        cols_to_drop = col_null_ratios[col_null_ratios > col_threshold].index
        df.drop(columns=cols_to_drop, inplace=True)
        

        # Update thresholds by reducing them for the next iteration
        row_threshold = max(0, row_threshold - threshold_step)
        col_threshold = max(0, col_threshold - threshold_step)


        # Stop condition if no columns or rows exceed the thresholds
        if all(col_null_ratios <= col_threshold) and all(row_null_ratios <= row_threshold):
            break

    return df

# Example usage
# df = pd.DataFrame(...)  # your dataframe
# cleaned_df = clean_data(df)

# %%
# Run the cleaning process
cleaned_df = clean_data(df)
cleaned_df
# Out:
#       record_id  import_phq9_score  import_gad7_score  high_total_sx_severity  \
# 0             1               17.0               16.0                    40.0
# 4             5                2.0                0.0                     9.0
# 5             6                2.0                3.0                    12.0
# 6             7               13.0                6.0                    48.0
# 8             9                4.0                0.0                     7.0
# ...         ...                ...                ...                     ...
# 2992       3012                2.0                1.0                    16.0
# 2996       3016                3.0                2.0                     4.0
# 2997       3017               15.0                6.0                    10.0
# 2998       3018                5.0                3.0                    22.0
# 2999       3019               10.0                2.0                    45.0
#
#       cerv_flex  cerv_ext  l_lat_flex  r_lat_flex  subocc_flex  subocc_ext  \
# 0          60.0      50.0        45.0        45.0         12.0        21.0
# 4          50.0      48.0        47.0        42.0         12.0        21.0
# 5          67.0      52.0        53.0        50.0         12.0        19.0
# 6          66.0      44.0        34.0        34.0         14.0        24.0
# 8          55.0      35.0        36.0        36.0         10.0        19.0
# ...         ...       ...         ...         ...          ...         ...
# 2992       47.0      71.0        41.0        38.0         18.0        24.0
# 2996       50.0      67.0        46.0        41.0         14.0        34.0
# 2997       66.0      76.0        28.0        34.0         15.0        34.0
# 2998       41.0      58.0        30.0        27.0         13.0        27.0
# 2999       60.0      66.0        41.0        38.0         10.0        35.0
#
#       ...  vor_horiz_nausea  vor_horiz_fogginess  vor_vert_headache  \
# 0     ...               1.0                  0.0                3.0
# 4     ...               0.0                  0.0                0.0
# 5     ...               1.0                  0.0                1.0
# 6     ...               1.0                  5.0                8.0
# 8     ...               0.0                  0.0                2.0
# ...   ...               ...                  ...                ...
# 2992  ...               0.0                  0.0                0.0
# 2996  ...               0.0                  0.0                1.0
# 2997  ...               0.0                  0.0                0.0
# 2998  ...               0.0                  0.0                3.0
# 2999  ...               0.0                  4.0                0.0
#
#       vor_vert_dizziness  vor_vert_nausea  vor_vert_fogginess  vmst_headache  \
# 0                    1.0              1.0                 0.0            3.0
# 4                    0.0              0.0                 0.0            0.0
# 5                    2.0              1.0                 0.0            1.0
# 6                    6.0              3.0                 5.0            8.0
# 8                    0.0              0.0                 0.0            2.0
# ...                  ...              ...                 ...            ...
# 2992                 0.0              0.0                 0.0            0.0
# 2996                 2.0              0.0                 0.0            1.0
# 2997                 0.0              0.0                 0.0            0.0
# 2998                 2.0              0.0                 0.0            3.0
# 2999                 6.0              0.0                 4.0            0.0
#
#       vmst_dizziness  vmst_nausea  vmst_fogginess
# 0                1.0          1.0             0.0
# 4                0.0          0.0             0.0
# 5                2.0          1.0             0.0
# 6                6.0          4.0             5.0
# 8                0.0          0.0             0.0
# ...              ...          ...             ...
# 2992             0.0          0.0             0.0
# 2996             2.0          0.0             0.0
# 2997             0.0          0.0             0.0
# 2998             2.0          0.0             0.0
# 2999             4.0          0.0             4.0
#
# [2338 rows x 48 columns]

# %%
# df.to_csv('Cleaned_concussion_11_01_ver2.csv', index=False)  
# print("Saved Cleaned_concussion_11_02.csv")

# %%
clean_col = []

for x in cleaned_df.columns:
    clean_col.append(x)

clean_col
# Out:
# ['record_id',
#  'import_phq9_score',
#  'import_gad7_score',
#  'high_total_sx_severity',
#  'cerv_flex',
#  'cerv_ext',
#  'l_lat_flex',
#  'r_lat_flex',
#  'subocc_flex',
#  'subocc_ext',
#  'l_cerv_rot',
#  'r_cerv_rot',
#  'bess_double_ec',
#  'bess_tandem_ec',
#  'bess_single_ec',
#  'voms_headache',
#  'voms_dizziness',
#  'voms_nausea',
#  'voms_fogginess',
#  'smoothpursuits_headache',
#  'smoothpursuits_dizziness',
#  'smoothpursuits_nausea',
#  'smoothpursuits_fogginess',
#  'saccades_horiz_headache',
#  'saccades_horiz_dizziness',
#  'saccades_horiz_nausea',
#  'saccades_horiz_fogginess',
#  'saccades_vert_headache',
#  'saccades_vert_dizziness',
#  'saccades_vert_nausea',
#  'saccades_vert_fogginess',
#  'npc_headache',
#  'npc_dizziness',
#  'npc_nausea',
#  'npc_fogginess',
#  'npc_measure',
#  'vor_horiz_headache',
#  'vor_horiz_dizziness',
#  'vor_horiz_nausea',
#  'vor_horiz_fogginess',
#  'vor_vert_headache',
#  'vor_vert_dizziness',
#  'vor_vert_nausea',
#  'vor_vert_fogginess',
#  'vmst_headache',
#  'vmst_dizziness',
#  'vmst_nausea',
#  'vmst_fogginess']

# %%
#removed columns

# Using list comprehension
result = [x for x in all_col if x not in clean_col]

# Using sets
result = list(set(all_col) - set(clean_col))

print(result)
# Out:
# ['cns_cognitive_flexibility', 'cns_verbal_mem', 'cns_neurocog_index', 'cns_composite_mem', 'cns_exec_fxn', 'cns_rxn_time', 'cns_simple_attention', 'cns_complex_attention', 'cns_visual_mem', 'cns_psychomotor_speed', 'cns_motor_speed', 'cns_processing_speed']
